# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data = pd.read_csv('/Users/amitishashemi/Documents/Computers2.csv')
data
# Out:
#       Unnamed: 0   price  speed      hd   ram  screen   cd multi premium  \
# 0            1.0  1499.0   25.0    80.0   4.0    14.0   no    no     yes
# 1            3.0  1595.0   25.0   170.0   4.0    15.0   no    no     yes
# 2            4.0  1849.0   25.0   170.0   8.0    14.0   no    no      no
# 3            7.0  1720.0   25.0   170.0   4.0    14.0  yes    no     yes
# 4           14.0  2295.0   25.0   245.0   8.0    14.0   no    no     yes
# ...          ...     ...    ...     ...   ...     ...  ...   ...     ...
# 6259      6210.0  3244.0   75.0  1600.0  32.0    15.0  yes    no     yes
# 6260      6226.0  3244.0   75.0  1600.0  32.0    15.0  yes    no     yes
# 6261      6227.0  3123.0   75.0  1600.0  32.0    15.0  yes   yes     yes
# 6262      6236.0  3290.0   75.0  1600.0  32.0    17.0  yes    no     yes
# 6263      6245.0  3054.0   75.0  1600.0  32.0    15.0  yes    no     yes
#
#        ads  trend
# 0     94.0    1.0
# 1     94.0    1.0
# 2     94.0    1.0
# ...

# %%
data = pd.get_dummies(data, columns=['cd'], ['multi'], ['premium'], drop_first=True)
# Out:
#   File "/var/folders/3f/9ykzv49x4mn1z_mgr9zm7kwm0000gn/T/ipykernel_1181/80259463.py", line 1
#     data = pd.get_dummies(data, columns=['cd'], ['multi'], ['premium'], drop_first=True)
#                                                                                        ^
# SyntaxError: positional argument follows keyword argument

# %%
# حذف ستون Unnamed: 0
data2 = data.drop(columns=['Unnamed: 0'])
data2
# Out:
#        price  speed      hd   ram  screen   ads  trend  cd_yes  multi_yes  \
# 0     1499.0   25.0    80.0   4.0    14.0  94.0    1.0       0          0
# 1     1595.0   25.0   170.0   4.0    15.0  94.0    1.0       0          0
# 2     1849.0   25.0   170.0   8.0    14.0  94.0    1.0       0          0
# 3     1720.0   25.0   170.0   4.0    14.0  94.0    1.0       1          0
# 4     2295.0   25.0   245.0   8.0    14.0  94.0    1.0       0          0
# ...      ...    ...     ...   ...     ...   ...    ...     ...        ...
# 6259  3244.0   75.0  1600.0  32.0    15.0  39.0   34.0       1          0
# 6260  3244.0   75.0  1600.0  32.0    15.0  39.0   35.0       1          0
# 6261  3123.0   75.0  1600.0  32.0    15.0  39.0   35.0       1          1
# 6262  3290.0   75.0  1600.0  32.0    17.0  39.0   35.0       1          0
# 6263  3054.0   75.0  1600.0  32.0    15.0  39.0   35.0       1          0
#
#       premium_yes
# 0               1
# 1               1
# 2               0
# ...

# %%
df = pd.DataFrame(data2) 
df
# Out:
#        price  speed      hd   ram  screen   ads  trend  cd_yes  multi_yes  \
# 0     1499.0   25.0    80.0   4.0    14.0  94.0    1.0       0          0
# 1     1595.0   25.0   170.0   4.0    15.0  94.0    1.0       0          0
# 2     1849.0   25.0   170.0   8.0    14.0  94.0    1.0       0          0
# 3     1720.0   25.0   170.0   4.0    14.0  94.0    1.0       1          0
# 4     2295.0   25.0   245.0   8.0    14.0  94.0    1.0       0          0
# ...      ...    ...     ...   ...     ...   ...    ...     ...        ...
# 6259  3244.0   75.0  1600.0  32.0    15.0  39.0   34.0       1          0
# 6260  3244.0   75.0  1600.0  32.0    15.0  39.0   35.0       1          0
# 6261  3123.0   75.0  1600.0  32.0    15.0  39.0   35.0       1          1
# 6262  3290.0   75.0  1600.0  32.0    17.0  39.0   35.0       1          0
# 6263  3054.0   75.0  1600.0  32.0    15.0  39.0   35.0       1          0
#
#       premium_yes
# 0               1
# 1               1
# 2               0
# ...

# %%
df2=df.dropna()
df2
# Out:
#        price  speed      hd   ram  screen   ads  trend  cd_yes  multi_yes  \
# 0     1499.0   25.0    80.0   4.0    14.0  94.0    1.0       0          0
# 1     1595.0   25.0   170.0   4.0    15.0  94.0    1.0       0          0
# 2     1849.0   25.0   170.0   8.0    14.0  94.0    1.0       0          0
# 3     1720.0   25.0   170.0   4.0    14.0  94.0    1.0       1          0
# 4     2295.0   25.0   245.0   8.0    14.0  94.0    1.0       0          0
# ...      ...    ...     ...   ...     ...   ...    ...     ...        ...
# 6259  3244.0   75.0  1600.0  32.0    15.0  39.0   34.0       1          0
# 6260  3244.0   75.0  1600.0  32.0    15.0  39.0   35.0       1          0
# 6261  3123.0   75.0  1600.0  32.0    15.0  39.0   35.0       1          1
# 6262  3290.0   75.0  1600.0  32.0    17.0  39.0   35.0       1          0
# 6263  3054.0   75.0  1600.0  32.0    15.0  39.0   35.0       1          0
#
#       premium_yes
# 0               1
# 1               1
# 2               0
# ...

# %%
df2.describe()
# Out:
#              price        speed           hd          ram       screen  \
# count  6259.000000  6259.000000  6259.000000  6259.000000  6259.000000
# mean   2219.576610    52.011024   416.601694     8.286947    14.608723
# std     580.803956    21.157735   258.548445     5.631099     0.905115
# min     949.000000    25.000000    80.000000     2.000000    14.000000
# 25%    1794.000000    33.000000   214.000000     4.000000    14.000000
# 50%    2144.000000    50.000000   340.000000     8.000000    14.000000
# 75%    2595.000000    66.000000   528.000000     8.000000    15.000000
# max    5399.000000   100.000000  2100.000000    32.000000    17.000000
#
#                ads        trend       cd_yes    multi_yes  premium_yes
# count  6259.000000  6259.000000  6259.000000  6259.000000  6259.000000
# mean    221.301007    15.926985     0.464611     0.139479     0.902221
# std      74.835284     7.873984     0.498786     0.346474     0.297040
# ...

# %%
plt.scatter(df2['hd'],df2['price'])
plt.xlabel("hd")
plt.ylabel("price")
plt.grid()
plt.show()

# %%
x_values = data['trend']
y_values = data['price']
plt.scatter(x_values, y_values)
plt.xlabel("trend")
plt.ylabel("price")
plt.grid()
plt.show()

# %%
x_values = data['screen']
y_values = data['price']
plt.scatter(x_values, y_values)
plt.xlabel("screen")
plt.ylabel("price")
plt.grid()
plt.show()

# %%
x_values = data['ads']
y_values = data['price']
plt.scatter(x_values, y_values)
plt.xlabel("ads")
plt.ylabel("price")
plt.grid()
plt.show()

# %%
x_values = data['ram']
y_values = data['price']
plt.scatter(x_values, y_values)
plt.xlabel("ram")
plt.ylabel("price")
plt.grid()
plt.show()

# %%
x_values = data['speed']
y_values = data['price']
plt.scatter(x_values, y_values)
plt.xlabel("speed")
plt.ylabel("price")
plt.grid()
plt.show()

# %%
plt.scatter(df2['cd_yes'],df2['price'])
plt.xlabel("cd_yes")
plt.ylabel("price")
plt.grid()
plt.show()

# %%
plt.scatter(df2['multi_yes'],df2['price'])
plt.xlabel("multi_yes")
plt.ylabel("price")
plt.grid()
plt.show()

# %%
plt.scatter(df2['premium_yes'],df2['price'])
plt.xlabel("premium_yes")
plt.ylabel("price")
plt.grid()
plt.show()
